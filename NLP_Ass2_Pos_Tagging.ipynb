# %% [markdown]
# <a href="https://colab.research.google.com/github/krystal826/NLP-Assignment-2/blob/main/NLP_Ass2_Pos_Tagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# To get furthur info about NNP and its example of words
nltk.download('tagsets')
nltk.download('universal_tagset')
nltk.help.upenn_tagset('NNP')
# Out:
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...

# %%
from google.colab import drive
drive.mount('/content/drive')
text = open('/content/drive/MyDrive/Ass corpus.txt', 'r').read()
corpus = nltk.sent_tokenize(text)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print("Total sentences in doc = ", len(corpus))
for sentence in corpus:
  print(sentence)
# Out:
# Total sentences in doc =  77
# "Malaysia has updated its Covid-19 testing requirements for international and local travellers arriving in the country under three travel schemes."
# "Those using the Vaccinated Travel Lane (VTL) by air and land, the Langkawi International Travel Bubble (LITB), and the One Stop Centre (OSC) for short-term business visitors will have to undergo additional Covid-19 tests for six days after arriving in Malaysia."
# "The new requirement will also apply to travellers from Singapore."
# "Health Minister Khairy Jamaluddin said the requirement, which will take effect from today, aims to strengthen the Ministry of Health’s existing precautionary and control measures to prevent the transmission and spread of the Omicron variant in the country."
# ...

# %%
word = word_tokenize(text)
nltk.pos_tag(word)
# Out:
# [('``', '``'),
#  ('Malaysia', 'NN'),
#  ('has', 'VBZ'),
#  ('updated', 'VBN'),
#  ('its', 'PRP$'),
#  ('Covid-19', 'NNP'),
#  ('testing', 'NN'),
#  ('requirements', 'NNS'),
#  ('for', 'IN'),
#  ('international', 'JJ'),
#  ('and', 'CC'),
#  ('local', 'JJ'),
#  ('travellers', 'NNS'),
#  ('arriving', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('country', 'NN'),
#  ('under', 'IN'),
#  ('three', 'CD'),
#  ('travel', 'NN'),
#  ('schemes', 'NNS'),
#  ('.', '.'),
#  ("''", "''"),
#  ('``', '``'),
#  ('Those', 'DT'),
#  ('using', 'VBG'),
#  ('the', 'DT'),
#  ('Vaccinated', 'NNP'),
#  ('Travel', 'NNP'),
#  ('Lane', 'NNP'),
#  ('(', '('),
#  ('VTL', 'NNP'),
#  (')', ')'),
#  ('by', 'IN'),
#  ('air', 'NN'),
#  ('and', 'CC'),
#  ('land', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Langkawi', 'NNP'),
#  ('International', 'NNP'),
#  ('Travel', 'NNP'),
#  ('Bubble', 'NNP'),
#  ('(', '('),
#  ('LITB', 'NNP'),
#  (')', ')'),
#  (',', ','),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('One', 'CD'),
# ...
